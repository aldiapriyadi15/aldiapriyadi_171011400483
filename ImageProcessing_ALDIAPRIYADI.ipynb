# %% [markdown]
# # <font color = "green">python : Image Processing</font>

# %% [markdown]
# ## <font color = "red">Method 1</font>
# ## <font color = "black">Using Pillow (PIL) Module</font>

# %%
# importing PIL Module
from PIL import Image

# Read Image, which is in the same folder
img = Image.open('./sunset.jpg')

# Display.Image
img.show()

# %% [markdown]
# ## <font color = "red">Method 1.2</font>
# ## <font color = "black">Using Pillow (PIL) with matplotlib Module</font>

# %%
# importing PIL Module
from PIL import Image
# importing matplotlib Module
import matplotlib.pyplot as plt

# Read Image, which is in the same folder
img = Image.open('./sunset.jpg')

# Using matplotlib module to display the image
plt.imshow(img)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## <font color = "red">Method 2</font>
# ## <font color = "black">Using matplotlib Module</font>

# %%
# importing matplotlib Modules
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Read the image, whish is in the same folder
img = mpimg.imread('./sunset.jpg')

# Display the image
plt.imshow(img)

# %% [markdown]
# ## <font color = "red">Method 3</font>
# ## <font color = "black">Using imageio with matplotlib Module</font>

# %%
# importing imageio Module
import imageio
# importing matplotlib Module
import matplotlib.pyplot as plt

# Read the image by imageio Module
img = imageio.imread('./sunset.jpg')

# Display the image by using matplotlib 
plt.imshow(img)

# %% [markdown]
# ## <font color = "red">Method 4</font>
# ## <font color = "black">Using openCV Module</font>

# %%
# importing opencv-python (cv2) Module
import cv2 as cv

# Read the image
img = cv.imread ('./sunset.jpg',1)
# NB: 1 : cv.IMREAD_COLOR = to loads color image, transparency neglected
# 0: CV.IMREAD_GRAYSCALE = to loads image in grayscale mode
# -1: cv.IMREAD_UNCHANGED = to loads image including as such alpha channe

# Display image
cv.imshow('windowTitle', img)

# to display image until you press any key in keyboard
cv.waitKey(0)

# to destroy all windows
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-8033bdc85ea0> in <module>
#       1 # importing opencv-python (cv2) Module
# ----> 2 import cv2 as cv
#       3
#       4 # Read the image
#       5 img = cv.imread ('./sunset.jpg',1)
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## <font color = "red">Method 5</font>
# ## <font color = "black">Using openCV with matplotlib Module</font>

# %%
# importing opencv-python (cv2) Module
import cv2 as cv
# importing matplotlib
import matplotlib.pyplot as plt

# Read the image in color mode mode
img = cv.imread ('./sunset.jpg',1)
# Convert from BGR Color mode to RGB Color mode
RGBimg = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display image using matplotlib
plt.imshow(RGBimg)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-d2d51d8b0040> in <module>
#       1 # importing opencv-python (cv2) Module
# ----> 2 import cv2 as cv
#       3 # importing matplotlib
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# ## the problem is that openCV return image in BGR Color mode
# ## matplotlib uses RGB Color mode
# ## So wh have to convert from BGR mode to RGB mode
